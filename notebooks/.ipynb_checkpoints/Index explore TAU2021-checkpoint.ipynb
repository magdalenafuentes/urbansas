# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../')

import project_paths
import project_params

# %matplotlib notebook

# %% [markdown]
# # Load TAU2021 index

# %%
index_path = project_paths.index_folder.joinpath('TAU2021.json')
with index_path.open() as f:
    index = json.load(f)

# %%
df_index = pd.DataFrame.from_dict(index,orient='index')
df_index
# Out:
#                                                   path  \
# 265  development/audio/street_traffic-barcelona-161...
# 266  development/audio/street_traffic-barcelona-161...
# 267  development/audio/street_traffic-barcelona-161...
# 268  development/audio/street_traffic-barcelona-161...
# 269  development/audio/street_traffic-barcelona-161...
# ..                                                 ...
# 604  development/audio/street_traffic-milan-1011-43...
# 605  development/audio/street_traffic-milan-1087-40...
# 606  development/audio/street_traffic-milan-1087-41...
# 607  development/audio/street_traffic-milan-1087-41...
# 608  development/audio/street_traffic-milan-1094-42...
#
#                                                 events  \
# 265  [{'label': 'car', 'start': 0.294, 'end': 3.106...
# 266  [{'label': 'car', 'start': 4.752, 'end': 7.273...
# 267  [{'label': 'car', 'time': [0.0, 0.5, 1.0, 1.5,...
# 268  [{'label': 'car', 'start': 1.565, 'end': 8.919...
# ...

# %% [markdown]
# # Analyze azimuth distribution

# %%
ds_azimuth = df_index['events'].map(lambda events: [ list(az for az in event['azimuth']) for event in events if 'azimuth' in event  ])
ds_azimuth = ds_azimuth.map(lambda x: np.concatenate(x) if len(x) else np.zeros(0))

# %%
all_azimuth = np.concatenate(ds_azimuth.to_numpy())

# %%
num_regions = project_params.num_regions
fov = project_params.fov
region_angle = fov/num_regions

plt.figure(figsize=(9,4))
plt.hist(all_azimuth,bins=np.linspace(-fov/2,fov/2,num_regions+1))
plt.grid()
plt.title(f'Azimuth distribution, {num_regions} regions, {region_angle:.0f} deg per region')
plt.xlabel('Azimuth [deg]')
plt.ylabel('Count')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="900">
